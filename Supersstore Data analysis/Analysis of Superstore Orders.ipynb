# %% [markdown]
# #Import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# #Read data

# %%
dataset = pd.read_excel("Superstore_USA.xlsx")

# %% [markdown]
# #Explore the dataset

# %%
dataset.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
dataset.shape
# Out:
# (9426, 24)

# %% [markdown]
# #Find the null values present in dataset

# %%
dataset.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %% [markdown]
# #fill null values in dataset with mean value

# %%
dataset.fillna({'Product Base Margin': dataset['Product Base Margin'].mean()}, inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %% [markdown]
# #explore Order Priority frequncy

# %%
dataset['Order Priority'].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1804
# Critical            1
# Name: count, dtype: int64

# %%
dataset['Order Priority'].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical', 'Critical '],
#       dtype=object)

# %%
dataset['Order Priority'] = dataset['Order Priority'].replace("Critical ","Critical")

# %%
dataset['Order Priority'].value_counts()
# Out:
# Order Priority
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1805
# Name: count, dtype: int64

# %% [markdown]
# Plot the graph for count of Order Priority

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Order Priority", data=dataset)
plt.title("Count of Order Priority")
plt.savefig("Count of Order Priority.jpg")
plt.show()

# %% [markdown]
# #Analyzing Shipping Mode order counts

# %%
dataset['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: count, dtype: int64

# %%
x = dataset['Ship Mode'].value_counts().index
y = dataset['Ship Mode'].value_counts().values

# %%
plt.figure(figsize=(5,4))
plt.pie(y, labels=x,startangle= 60, autopct="%0.2f%%")
plt.legend(loc=2)
plt.savefig("Percentage of orders shipping by mode.jpg")
plt.show()

# %% [markdown]
# #Analyzing Shipping Mode order counts by the product category

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Ship Mode", data=dataset,hue="Product Category")
plt.savefig("Frequency of shipping mode by category.jpg")
plt.show()

# %% [markdown]
# #Analyzing which segment is placing more orders

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Customer Segment", data=dataset)
plt.savefig("Count of orders by Customer Segment.jpg")
plt.show()

# %% [markdown]
# #categories with frequency of customers

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Product Category", data=dataset)
plt.savefig("Count of orders by product category.jpg")
plt.show()

# %% [markdown]
# #customers count in segment of office supplies sub category wise

# %%
plt.figure(figsize=(13,7))
sns.countplot(x="Product Category", data=dataset[dataset['Product Category']=="Office Supplies"],hue="Product Sub-Category")
plt.savefig("frequency of office supplies products by sub-category.jpg")
plt.show()

# %% [markdown]
# #customers count in segment of technology sub category wise

# %%
plt.figure(figsize=(13,7))
sns.countplot(x="Product Category", data=dataset[dataset['Product Category']=="Technology"],hue="Product Sub-Category")
plt.savefig("frequency of technology products by sub-category.jpg")
plt.show()

# %% [markdown]
# #customers count in segment of furniture sub category wise

# %%
plt.figure(figsize=(13,7))
sns.countplot(x="Product Category", data=dataset[dataset['Product Category']=="Furniture"],hue="Product Sub-Category")
plt.savefig("frequency of furniture products by sub-category.jpg")
plt.show()

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9426 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %% [markdown]
# #Extracting only Year from the Date column and adding to new column

# %%
dataset["Order Year"] = dataset['Order Date'].dt.year

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9426 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
dataset['Order Year'].value_counts()
# Out:
# Order Year
# 2013    3054
# 2012    2241
# 2011    2179
# 2010    1952
# Name: count, dtype: int64

# %% [markdown]
# #Now analyzing order frequency by year

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Order Year", data=dataset)
plt.savefig("Order count by year.jpg")
plt.show()

# %% [markdown]
# #plotting sum of profits made by the Product category

# %%
plt.figure(figsize=(6,4))
sns.barplot(x="Product Category", y="Profit",data=dataset,estimator="sum")
plt.savefig("sum of profit by product category.jpg")
plt.show()

# %%
dataset['State or Province'].value_counts()[:5]
# Out:
# State or Province
# California    1021
# Texas          646
# Illinois       584
# New York       574
# Florida        522
# Name: count, dtype: int64

# %%
dataset['State or Province'].value_counts()[-1:-6:-1]
# Out:
# State or Province
# Delaware        15
# Rhode Island    20
# Wyoming         21
# South Dakota    28
# North Dakota    34
# Name: count, dtype: int64

# %% [markdown]
# #Base Margin by the Product Category

# %%
plt.figure(figsize=(6,4))
sns.barplot(x="Product Category", y="Product Base Margin",data=dataset,estimator="sum")
plt.savefig("sum of base margin by product category.jpg")
plt.show()
